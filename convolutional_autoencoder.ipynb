# %% [markdown]
# Convolution Auto Encoders

# %%
import keras
from keras import layers

#input image
input_img = keras.Input(shape=(28,28,1)) #input shape of the MNIST dataset

#encoded representation of the input with convolution
#there can be more than one layers for stacking in case of deep auto encoders
x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)
#adding the encoder layer with l1 regularization so that fewer neurons fire at a time for each training ephoc
#encoded_layer = layers.Dense(encoded_no, activation='relu', activity_regularizer = keras.regularizers.l1(10e-5))(input_img)

#decoded representaion of the input
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

# %%
#creating a model
autoencoder = keras.Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

#load the MNIST dataset
from keras.datasets import mnist
import numpy as np
(x_train, _), (x_test, _) = mnist.load_data()

#normalize the dataset
x_train = x_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
x_train = np.reshape(x_train, (len(x_train), 28, 28, 1))
x_test = np.reshape(x_test, (len(x_test), 28, 28, 1))
print(x_train.shape)
print(x_test.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
#fitting the autoencoder model
autoencoder.fit(x_train, x_train,
                epochs=100,  #training ephoc can be increase after using the regularizer as the chances of overfitting decreses
                batch_size=256,
                shuffle=True,
                validation_data=(x_test, x_test))
# Out:
# Epoch 1/100
# 235/235 [==============================] - 38s 151ms/step - loss: 0.2499 - val_loss: 0.1601
# Epoch 2/100
# 235/235 [==============================] - 35s 151ms/step - loss: 0.1471 - val_loss: 0.1362
# Epoch 3/100
# 235/235 [==============================] - 36s 151ms/step - loss: 0.1308 - val_loss: 0.1242
# Epoch 4/100
# 235/235 [==============================] - 35s 150ms/step - loss: 0.1225 - val_loss: 0.1188
# Epoch 5/100
# 235/235 [==============================] - 36s 153ms/step - loss: 0.1179 - val_loss: 0.1149
# Epoch 6/100
# 235/235 [==============================] - 34s 146ms/step - loss: 0.1147 - val_loss: 0.1125
# Epoch 7/100
# 235/235 [==============================] - 27s 116ms/step - loss: 0.1123 - val_loss: 0.1106
# Epoch 8/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.1104 - val_loss: 0.1084
# Epoch 9/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.1088 - val_loss: 0.1068
# Epoch 10/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.1075 - val_loss: 0.1055
# Epoch 11/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.1062 - val_loss: 0.1044
# Epoch 12/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.1053 - val_loss: 0.1042
# Epoch 13/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.1044 - val_loss: 0.1027
# Epoch 14/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.1035 - val_loss: 0.1027
# Epoch 15/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.1027 - val_loss: 0.1011
# Epoch 16/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.1020 - val_loss: 0.1004
# Epoch 17/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.1013 - val_loss: 0.0998
# Epoch 18/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.1007 - val_loss: 0.0998
# Epoch 19/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.1002 - val_loss: 0.0990
# Epoch 20/100
# 235/235 [==============================] - 28s 118ms/step - loss: 0.0996 - val_loss: 0.0982
# Epoch 21/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.0991 - val_loss: 0.0977
# Epoch 22/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.0987 - val_loss: 0.0973
# Epoch 23/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.0982 - val_loss: 0.0968
# Epoch 24/100
# 235/235 [==============================] - 28s 118ms/step - loss: 0.0979 - val_loss: 0.0974
# Epoch 25/100
# 235/235 [==============================] - 28s 118ms/step - loss: 0.0975 - val_loss: 0.0963
# Epoch 26/100
# 235/235 [==============================] - 28s 118ms/step - loss: 0.0972 - val_loss: 0.0959
# Epoch 27/100
# 235/235 [==============================] - 27s 116ms/step - loss: 0.0968 - val_loss: 0.0956
# Epoch 28/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0965 - val_loss: 0.0952
# Epoch 29/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0963 - val_loss: 0.0953
# Epoch 30/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0960 - val_loss: 0.0947
# Epoch 31/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0958 - val_loss: 0.0949
# Epoch 32/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0955 - val_loss: 0.0942
# Epoch 33/100
# 235/235 [==============================] - 28s 119ms/step - loss: 0.0953 - val_loss: 0.0940
# Epoch 34/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.0951 - val_loss: 0.0939
# Epoch 35/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.0949 - val_loss: 0.0936
# Epoch 36/100
# 235/235 [==============================] - 27s 116ms/step - loss: 0.0948 - val_loss: 0.0935
# Epoch 37/100
# 235/235 [==============================] - 32s 138ms/step - loss: 0.0945 - val_loss: 0.0934
# Epoch 38/100
# 235/235 [==============================] - 30s 129ms/step - loss: 0.0944 - val_loss: 0.0932
# Epoch 39/100
# 235/235 [==============================] - 28s 119ms/step - loss: 0.0943 - val_loss: 0.0933
# Epoch 40/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.0941 - val_loss: 0.0928
# Epoch 41/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0941 - val_loss: 0.0929
# Epoch 42/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0938 - val_loss: 0.0932
# Epoch 43/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0937 - val_loss: 0.0929
# Epoch 44/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0936 - val_loss: 0.0924
# Epoch 45/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.0934 - val_loss: 0.0923
# Epoch 46/100
# 235/235 [==============================] - 27s 114ms/step - loss: 0.0934 - val_loss: 0.0923
# Epoch 47/100
# 235/235 [==============================] - 27s 116ms/step - loss: 0.0932 - val_loss: 0.0919
# Epoch 48/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.0930 - val_loss: 0.0918
# Epoch 49/100
# 235/235 [==============================] - 26s 113ms/step - loss: 0.0930 - val_loss: 0.0917
# Epoch 50/100
# 235/235 [==============================] - 26s 113ms/step - loss: 0.0928 - val_loss: 0.0916
# Epoch 51/100
# 235/235 [==============================] - 26s 113ms/step - loss: 0.0928 - val_loss: 0.0920
# Epoch 52/100
# 235/235 [==============================] - 27s 114ms/step - loss: 0.0926 - val_loss: 0.0917
# Epoch 53/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.0925 - val_loss: 0.0913
# Epoch 54/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0924 - val_loss: 0.0913
# Epoch 55/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0923 - val_loss: 0.0915
# Epoch 56/100
# 235/235 [==============================] - 26s 113ms/step - loss: 0.0923 - val_loss: 0.0911
# Epoch 57/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0921 - val_loss: 0.0910
# Epoch 58/100
# 235/235 [==============================] - 26s 113ms/step - loss: 0.0920 - val_loss: 0.0909
# Epoch 59/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.0920 - val_loss: 0.0912
# Epoch 60/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0919 - val_loss: 0.0907
# Epoch 61/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.0919 - val_loss: 0.0907
# Epoch 62/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0918 - val_loss: 0.0906
# Epoch 63/100
# 235/235 [==============================] - 27s 113ms/step - loss: 0.0917 - val_loss: 0.0907
# Epoch 64/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0916 - val_loss: 0.0910
# Epoch 65/100
# 235/235 [==============================] - 28s 117ms/step - loss: 0.0915 - val_loss: 0.0903
# Epoch 66/100
# 235/235 [==============================] - 29s 125ms/step - loss: 0.0915 - val_loss: 0.0908
# Epoch 67/100
# 235/235 [==============================] - 28s 120ms/step - loss: 0.0915 - val_loss: 0.0932
# Epoch 68/100
# 235/235 [==============================] - 29s 125ms/step - loss: 0.0914 - val_loss: 0.0903
# Epoch 69/100
# 235/235 [==============================] - 28s 120ms/step - loss: 0.0912 - val_loss: 0.0901
# Epoch 70/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0912 - val_loss: 0.0902
# Epoch 71/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0912 - val_loss: 0.0900
# Epoch 72/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0912 - val_loss: 0.0906
# Epoch 73/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0910 - val_loss: 0.0899
# Epoch 74/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0910 - val_loss: 0.0901
# Epoch 75/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0909 - val_loss: 0.0899
# Epoch 76/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0909 - val_loss: 0.0897
# Epoch 77/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0908 - val_loss: 0.0900
# Epoch 78/100
# 235/235 [==============================] - 26s 111ms/step - loss: 0.0908 - val_loss: 0.0897
# Epoch 79/100
# 235/235 [==============================] - 26s 112ms/step - loss: 0.0908 - val_loss: 0.0897
# Epoch 80/100
# 235/235 [==============================] - 27s 117ms/step - loss: 0.0906 - val_loss: 0.0895
# Epoch 81/100
# 235/235 [==============================] - 28s 121ms/step - loss: 0.0906 - val_loss: 0.0896
# Epoch 82/100
# 235/235 [==============================] - 28s 119ms/step - loss: 0.0906 - val_loss: 0.0898
# Epoch 83/100
# 235/235 [==============================] - 30s 128ms/step - loss: 0.0905 - val_loss: 0.0894
# Epoch 84/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.0905 - val_loss: 0.0896
# Epoch 85/100
# 235/235 [==============================] - 30s 129ms/step - loss: 0.0905 - val_loss: 0.0893
# Epoch 86/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0904 - val_loss: 0.0895
# Epoch 87/100
# 235/235 [==============================] - 30s 128ms/step - loss: 0.0903 - val_loss: 0.0892
# Epoch 88/100
# 235/235 [==============================] - 27s 114ms/step - loss: 0.0903 - val_loss: 0.0895
# Epoch 89/100
# 235/235 [==============================] - 28s 120ms/step - loss: 0.0903 - val_loss: 0.0894
# Epoch 90/100
# 235/235 [==============================] - 29s 125ms/step - loss: 0.0902 - val_loss: 0.0897
# Epoch 91/100
# 235/235 [==============================] - 29s 123ms/step - loss: 0.0902 - val_loss: 0.0893
# Epoch 92/100
# 235/235 [==============================] - 28s 118ms/step - loss: 0.0901 - val_loss: 0.0891
# Epoch 93/100
# 235/235 [==============================] - 28s 119ms/step - loss: 0.0901 - val_loss: 0.0892
# Epoch 94/100
# 235/235 [==============================] - 31s 132ms/step - loss: 0.0902 - val_loss: 0.0894
# Epoch 95/100
# 235/235 [==============================] - 29s 122ms/step - loss: 0.0900 - val_loss: 0.0890
# Epoch 96/100
# 235/235 [==============================] - 27s 115ms/step - loss: 0.0900 - val_loss: 0.0891
# Epoch 97/100
# 235/235 [==============================] - 29s 123ms/step - loss: 0.0899 - val_loss: 0.0894
# Epoch 98/100
# 235/235 [==============================] - 29s 123ms/step - loss: 0.0898 - val_loss: 0.0888
# Epoch 99/100
# 235/235 [==============================] - 29s 125ms/step - loss: 0.0898 - val_loss: 0.0888
# Epoch 100/100
# 235/235 [==============================] - 30s 128ms/step - loss: 0.0898 - val_loss: 0.0889

# %%
# Encode and decode some digits
# Note that we take them from the *test* set
decoded_imgs = autoencoder.predict(x_test)
# Out:
# 313/313 [==============================] - 3s 9ms/step

# %%
import matplotlib.pyplot as plt

n = 10
plt.figure(figsize=(20, 4))
for i in range(1, n + 1):
    # Display original
    ax = plt.subplot(2, n, i)
    plt.imshow(x_test[i].reshape(28, 28))
    plt.title('Original Image')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # Display reconstruction
    ax = plt.subplot(2, n, i + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.title('Reconstructed')
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
